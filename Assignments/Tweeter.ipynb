# %% [markdown]
# # Tweetpy

# %%
import tweepy 
  
# Fill the X's with the credentials obtained by  
# following the above mentioned procedure. 
consumer_key = "FNCsgZTpa9ZGiWmLvHeA87ux2"
consumer_secret = "7C16I0r6xg9602WoD81aeG6600QsBwpZnx0YVSA986aunYB61X"
access_key = "275071458-4Q8w3slzgenRlHTQUW5qYxLxThPDoVXClNNKMVuW"
access_secret = "CzcopHBSZqlQUHwuNR0lzOYdRVlcY50oL7ZsLN6Is0aIW"
  
# Function to extract tweets 
def get_tweets(username): 
          
        # Authorization to consumer key and consumer secret 
        auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
  
        # Access to user's access key and access secret 
        auth.set_access_token(access_key, access_secret) 
  
        # Calling api 
        api = tweepy.API(auth) 
  
        # 200 tweets to be extracted 
        number_of_tweets=200
        tweets = api.user_timeline(screen_name=username) 
  
        # Empty Array 
        tmp=[]  
  
        # create array of tweet information: username,  
        # tweet id, date/time, text 
        tweets_for_csv = [tweet.text for tweet in tweets] # CSV file created  
        for j in tweets_for_csv: 
  
            # Appending tweets to the empty array tmp 
            tmp.append(j)  
  
        # Printing the tweets 
        print(tmp) 
  
  
# Driver code 
if __name__ == '__main__': 
  
    # Here goes the twitter handle for the user 
    # whose tweets are to be extracted. 
    get_tweets("astitvam")
# Out:
# ['RT @HarendraKS_IPS: It needs more courage to restrain oneself,otherwise such brutal attacks could be answered with bullets. But we worship…', '🇮🇳 1\n🇨🇳 0 https://t.co/2UGNs1ofxB', 'They expected farmers will die; but the bullet hit at the right spot!!\n\nIndia Today Takes Anchor Rajdeep Sardesai O… https://t.co/MWsYAoITPb', 'This is a major reason behind riot like situations. ‘Handle Delhi and forget Bengal’\nAward wapsi, not in my name, C… https://t.co/yWh2V70pqC', 'Hahha!! Finally they found someone who was killed in police firing! https://t.co/nx7vFyqLDw', 'After total failure in Hatras, Farmer’s agitation now they are planning for a nationwide riots! Time to be careful… https://t.co/Y6MqjhyQzH', '😢 https://t.co/4IYU1WroYp', 'ಇವರ ಬಯಕೆ ಇದ್ದದ್ದು ಅದೊಂದೇ. ಪೋಲೀಸರ ಗುಂಡು ಹಾರಬೇಕು, ಒಂದಿಬ್ಬರು ತಥಾಕಥಿತ ರೈತರು ಸಾಯಬೇಕು; ಶವ ಹಿಡಿದು ಇವರು ಆಂದೋಲನವನ್ನು ರಾಷ್ಟ್ರ… https://t.co/h2uWLCvUdS', 'RT @IAF_MCC: The third batch of three Rafale aircraft landed at an IAF base a short while ago. They flew over 700
# ...

# %% [markdown]
# # Extract 'Covid19' 10000 tweets

# %%
import tweepy
from tweepy import OAuthHandler
 
# Your Twittter App Credentials
consumer_key = "FNCsgZTpa9ZGiWmLvHeA87ux2"
consumer_secret = "7C16I0r6xg9602WoD81aeG6600QsBwpZnx0YVSA986aunYB61X"
access_token = "275071458-4Q8w3slzgenRlHTQUW5qYxLxThPDoVXClNNKMVuW"
access_token_secret = "CzcopHBSZqlQUHwuNR0lzOYdRVlcY50oL7ZsLN6Is0aIW"
 
# Calling API
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# Provide the keyword you want to pull the data e.g. "Python".
keyword = "#Covid19"
 
# Fetching tweets
tweets = api.search(keyword, count=10000, lang='en', exclude='retweets', tweet_mode='extended')
 
for item in tweets:
    print(item)
# Out:
# Status(_api=<tweepy.api.API object at 0x000001FE30226250>, _json={'created_at': 'Thu Jan 28 18:33:04 +0000 2021', 'id': 1354860056144183297, 'id_str': '1354860056144183297', 'full_text': 'The shortage of Toilet Paper has NOTHING to do with #COVID19 \n\nThe #ACC used literally all of it to come up with Clemsons 2021 Football Schedule. \n\n@PeterBurnsESPN @TBob53 @OneTeamOnePod @LSUBarstool @CulottaShow https://t.co/6wR2q96fea', 'truncated': False, 'display_text_range': [0, 212], 'entities': {'hashtags': [{'text': 'COVID19', 'indices': [52, 60]}, {'text': 'ACC', 'indices': [67, 71]}], 'symbols': [], 'user_mentions': [{'screen_name': 'PeterBurnsESPN', 'name': 'Peter Burns', 'id': 21926735, 'id_str': '21926735', 'indices': [148, 163]}, {'screen_name': 'TBob53', 'name': 'T-Bob Hebert', 'id': 314155396, 'id_str': '314155396', 'indices': [164, 171]}, {'screen_name': 'OneTeamOnePod', 'name': 'One Team, One Podcast.', 'id': 1237528709277659136, 'id_str': '1237528709277659136', 'indices': [172
# ...

# %%
import tweepy
from tweepy import OAuthHandler
 
# Your Twittter App Credentials
consumer_key = "FNCsgZTpa9ZGiWmLvHeA87ux2"
consumer_secret = "7C16I0r6xg9602WoD81aeG6600QsBwpZnx0YVSA986aunYB61X"
access_token = "275071458-4Q8w3slzgenRlHTQUW5qYxLxThPDoVXClNNKMVuW"
access_token_secret = "CzcopHBSZqlQUHwuNR0lzOYdRVlcY50oL7ZsLN6Is0aIW"
 
# Calling API
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# Provide the keyword you want to pull the data e.g. "Python".
keyword = "#Covid19"
#date_since = "2020-11-16"
 
# Fetching tweets
    
# Collect tweets
#tweets = tweepy.Cursor(api.search,
              #q=keyword,
              #lang="en", since=date_since).items(5)
        
tweets = tweepy.Cursor(api.search,
                       q=keyword, lang='en').items(100)

# Iterate and print tweets
#for tweet in tweets:
#    print(tweet.text)

users_locs = [[tweet.user.id, tweet.user.screen_name, tweet.user.location, 
               tweet.text, tweet.user.followers_count, tweet.user.friends_count,
              tweet.user.statuses_count] for tweet in tweets]
users_locs
# Out:
# [[25999072,
#   'jmsardo',
#   'Vigo, España',
#   '#Portugal #Breaking Government reintroduces border controls with #Spain for 15 days to stop #covid19 spread. From t… https://t.co/J1dP2umR6k',
#   7509,
#   4544,
#   49185],
#  [1684005398,
#   'supamano84',
#   '🌞🌍🌊',
#   "RT @RobinHoodNYC: New York City is now in a full-blown hunger crisis, and solving food insecurity is key to our community's #COVID19 recove…",
#   282,
#   1622,
#   80649],
#  [15113922,
#   'piyookochar',
#   'Jaipur | Benghazi | New York',
#   'RT @antonioguterres: The #COVID19 pandemic unleashed havoc in every country and every economy.\n\nNow is the time to secure the well-being of…',
#   247,
#   343,
#   3393],
#  [1318834986,
#   'BjrnBlomberg',
#   '',
#   'RT @mennisNY: @MediccGail @FinlayInstituto @BioCubaFarma @centro_cim @CIGBCuba @opscuba @OPSOMSMexico #COVID19 vaccine inequality will like…',
#   386,
#   839,
#   5903],
#  [89036251,
#   'randywsandberg',
#   'Tiny Blue Dot',
# ...

# %%
import pandas as pd

df = pd.DataFrame(data=users_locs, 
                    columns=['user_ID', 'user', "location", 'tweet','follower cnt', 'frd count', '# of tweets'])
df
# Out:
#                 user_ID             user                      location  \
# 0              25999072          jmsardo                  Vigo, España
# 1            1684005398       supamano84                           🌞🌍🌊
# 2              15113922      piyookochar  Jaipur | Benghazi | New York
# 3            1318834986     BjrnBlomberg
# 4              89036251   randywsandberg                 Tiny Blue Dot
# ..                  ...              ...                           ...
# 95  1272772353936654336      LFPubHealth             San Francisco, CA
# 96             62903214           neasam
# 97   879459933988585472       Davecl3069        San Francisco Bay Area
# 98           1322394026      DrJFriedman               Toronto, Canada
# 99  1126022291849142277  DBetterAcademia                United Kingdom
#
#                                                 tweet  follower cnt  \
# 0   #Portugal #Breaking Government reintroduces bo...          7509
# ...
